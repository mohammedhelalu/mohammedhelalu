# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedhelalu/mohammedhelalu/blob/main/pandas_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot()
data.plot(kind='line')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='pie')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='bar')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='barh')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='hist')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='box')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='kde')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='density')

# %%
import pandas as pd
data = pd.Series((3,6,9,8,5,4,2,6,3,5,8))

data.plot(kind='area')
